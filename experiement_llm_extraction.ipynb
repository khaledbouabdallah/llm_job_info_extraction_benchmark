# %% [markdown]
# ## Experiment Structure

# %%
# import .env variables
import os
from dotenv import load_dotenv
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
GIMINI_API_KEY = os.getenv("GIMINI_API_KEY")
ANTROPIC_API_KEY = os.getenv("ANTROPIC_API_KEY")

# %%
from openai import OpenAI
from anthropic import Anthropic
from google import genai
from google.genai import types
import outlines
import instructor
from ollama import Client
import openai


gimini_client = genai.Client(api_key=GIMINI_API_KEY)
openai_client = OpenAI(api_key=OPENAI_API_KEY)
antropic_client = Anthropic(api_key=ANTROPIC_API_KEY)
ollama_client = Client()

gemini = outlines.from_gemini(gimini_client, "gemini-2.5-flash-lite")
claude = instructor.from_anthropic(antropic_client) # doesn't work with outlines yet, so using instructor
chatgpt = outlines.from_openai(openai_client, "gpt-4o")


model = outlines.from_ollama(ollama_client, "smollm2:1.7b")

# %% [markdown]
# # start experiement code

# %%
from src import (
    JobEnrichment,
    ExtractionQuality,
    ExperimentConfig,
    extract_with_model,
    extract_with_cloud_model,
    EXTRACTION_PROMPT_DIRECT,
    EXTRACTION_PROMPT_EXAMPLES,
    create_judge_prompt,
    judge_extraction,
    ExperimentRunner,
    analyze_results
)
import pandas as pd
from datetime import datetime

# %% [markdown]
# ## Extraction System

# %%
print("Direct Prompt Preview:")
print(EXTRACTION_PROMPT_DIRECT[:200] + "...")
print("\n" + "="*50 + "\n")
print("Examples Prompt Preview:")
print(EXTRACTION_PROMPT_EXAMPLES[:200] + "...")

# %%
print("Schemas and extraction functions imported from src/")
print(f"JobEnrichment fields: {list(JobEnrichment.model_fields.keys())}")

# %% [markdown]
# ## Judge System

# %%
# Judge functions are now imported from src
# create_judge_prompt() and judge_extraction()

print("Judge evaluation functions imported from src/")
print("ExtractionQuality schema with 4 scores + detailed feedback")

# %% [markdown]
# ## Experiment Runner

# %%
print("ExperimentRunner class imported from src/runner.py")
print("analyze_results() function imported from src/runner.py")

# %% [markdown]
# ## RUN

# %%
import pandas as pd

jobs_df = pd.read_csv("jobs_sample.csv")

eng = jobs_df[jobs_df['description_language'] == "English"].head(15)
fr  = jobs_df[jobs_df['description_language'] == "French"].head(15)

jobs_df = pd.concat([eng, fr], ignore_index=True)

# %%
# df to list of dicts

jobs_list = jobs_df.to_dict(orient="records")
jobs_list[0]
# Out:
# {'title': 'Senior Machine Learning Engineer, Ads R&D',
#  'company': 'Spotify',
#  'location': 'New York, NY',
#  'description': "Engineering\nMachine Learning\nPermanent\nNew York\nOur mission on the Advertising Product & Technology team is to build a next generation advertising platform that aligns with our unique value proposition for audio and video. We work to scale the user experience for hundreds of millions of fans and hundreds of thousands of advertisers. This scale brings unique challenges as well as tremendous opportunities for our artists and creators.\n\nWe are seeking a Senior Machine Learning Engineer to join the Ad Engagement squad. Ad Engagement focuses on using machine learning to accurately predict how Spotify listeners will react to ads, helping advertisers minimize their costs while delivering a more relevant and enjoyable ad experience for listeners. Our core innovations include Multi-Task Learning models (MTL), and we are expanding into scalable sequence modeling with complex transformer architectures. Recently, we presented a paper about this in KDD Toronto and you can check out the latest details in the blog post here.\n\nWe are also seeking a Senior Machine Learning Engineer to join the Supply Personalization squad. Supply Personalization focuses on optimizing the volume, timing, and types of ad loads a user receives. By leveraging data, machine learning, causal inference, and large scale online experimentation, we aim to uncover and learn the most effective strategies for enhancing user experiences and driving business outcomes.\n\nWe are looking for someone with strong expertise in data analysis, online experimentation techniques, and large-scale ML and engineering systems; someone who is motivated by user and business problems as much as they are by technical problems, and who thrives under ambiguity, experimentation, and iteration. You will work directly on an array of product features that drive the optimal user experience for our ads. You will collaborate with our cross-functional teams to ideate, develop, and own complex technical solutions on our ad services technology platforms. As someone who shares our passion for building innovative ad experiences, you'll have a direct impact on how the world uses Spotify.\nWhat You'll Do\nDesign and implement machine learning systems for ad performance optimization.\nResearch and apply ML optimization strategies to balance multiple objectives effectively.\nWork on a paradigm shift modeling work for Ads that involves working on Sequence Transformer model for User-Ad Interaction, that works along a MTL model\nAnalyze data and use machine learning techniques to understand user behavior and improve ad experiences.\nCollaborate with backend engineers, data scientists, data engineers, and product managers to establish baselines, inform product decisions, and develop new technologies.\nWho You Are\nYou have professional experience in applied machine learning.\nYou have strong technical expertise in software engineering, data analysis, and machine learning.\nYou are proficient in programming languages such as Python, Java, or Scala.\nExperienced in Tensorflow or PyTorch and working with various aspects of the ML lifecycle\nYou have expertise in developing data pipelines using tools like Apache Beam or Spark.\nAs a plus, you may have experience with any of the following - LLMs, Ray, Adtech, or Recommender Systems.\nWhere You'll Be\nWe offer you the flexibility to work where you work best! For this role, you can be within the Americas region as long as we have a work location.\nThis team operates within the U.S. Eastern time zone for collaboration.\nLearn about life at Spotify\nThe United States base range for this position is $176,166.00 - $251,666.00, plus equity. The benefits available for this position include health insurance, six month paid parental leave, 401(k) retirement plan, monthly meal allowance, 23 paid days off, 13 paid flexible holidays, paid sick leave. This range encompasses multiple levels. Leveling is determined during the interview process. Placement in a ...
#  'description_length': 5796,
#  'description_language': 'English'}

# %%
JUDGES =  {"gpt-4o": chatgpt,
           "claude-sonnet-4-5":claude}

CLOUD_EXTRACTORS = {"gemini-2.5-flash-lite": gemini,
                   }


# Configure
config = ExperimentConfig(
    local_models=[
                 "qwen3:1.7b-q4_K_M",
                 "qwen3:4b-q4_K_M",
                 "qwen3:4b-instruct-2507-q4_K_M",
                 "qwen3:8b-q4_K_M",
                 "qwen3:14b-q4_K_M",
                 "qwen3:30b"
                 ],
    cloud_models=["gemini-2.5-flash-lite"],
    judge_models=["claude-sonnet-4-5", "gpt-4o"],
    temperature=0.0,  # Deterministic outputs
    num_jobs=30
)

print("=== EXPERIMENT CONFIGURATION ===")
print(f"Testing {len(config.local_models)} local models: {config.local_models}")
print(f"Testing {len(config.cloud_models)} cloud models: {config.cloud_models}")
print(f"Using {len(config.judge_models)} judges: {config.judge_models}")
print(f"Testing 2 prompt versions: direct, examples")
print(f"Processing {config.num_jobs} jobs")
print(f"Total extractions per prompt: {(len(config.local_models) + len(config.cloud_models)) * config.num_jobs}")
print(f"Total extractions (both prompts): {(len(config.local_models) + len(config.cloud_models)) * config.num_jobs * 2}")
print(f"Total evaluations: {(len(config.local_models) + len(config.cloud_models)) * config.num_jobs * 2 * len(config.judge_models)}")
print("\n" + "="*50 + "\n")

# Run experiment with BOTH prompts
runner = ExperimentRunner(
    config,
    jobs_list,
    JUDGES,
    CLOUD_EXTRACTORS,
    EXTRACTION_PROMPT_DIRECT,
    EXTRACTION_PROMPT_EXAMPLES
)
results_df = runner.run_experiment()

print("\n" + "="*50)
print("EXPERIMENT COMPLETED!")
print("="*50 + "\n")

# Save results with ALL new columns
results_df.to_csv("extraction_experiment_results.csv", index=False, escapechar='\\')
results_df.to_pickle("extraction_experiment_results.pkl")
print("✓ Results saved to: extraction_experiment_results.csv and .pkl")
print(f"✓ New columns included: prompt_version, input_tokens, output_tokens, description_length, description_language")
# Out:
# === EXPERIMENT CONFIGURATION ===
# Testing 6 local models: ['qwen3:1.7b-q4_K_M', 'qwen3:4b-q4_K_M', 'qwen3:4b-instruct-2507-q4_K_M', 'qwen3:8b-q4_K_M', 'qwen3:14b-q4_K_M', 'qwen3:30b']
# Testing 1 cloud models: ['gemini-2.5-flash-lite']
# Using 2 judges: ['claude-sonnet-4-5', 'gpt-4o']
# Testing 2 prompt versions: direct, examples
# Processing 30 jobs
# Total extractions per prompt: 210
# Total extractions (both prompts): 420
# Total evaluations: 840
#
# ==================================================
#
#
# ======================================================================
# COMBINATION 1/14: qwen3:1.7b-q4_K_M + direct
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#     ✓ Extracted in 3.06s (1261→295 tokens)
#     ✓ Extracted in 3.06s (1261→295 tokens)
#
#   [2/30] Data Engineer...
#
#   [2/30] Data Engineer...
#     ✓ Extracted in 3.77s (1380→181 tokens)
#     ✓ Extracted in 3.77s (1380→181 tokens)
#
#   [3/30] Data Scientist...
#
#   [3/30] Data Scientist...
#     ✓ Extracted in 3.70s (1139→365 tokens)
#     ✓ Extracted in 3.70s (1139→365 tokens)
#
#   [4/30] Data Scientist, Music Expression...
#
#   [4/30] Data Scientist, Music Expression...
#     ✓ Extracted in 4.99s (1209→310 tokens)
#     ✓ Extracted in 4.99s (1209→310 tokens)
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#     ✓ Extracted in 2.96s (1217→249 tokens)
#     ✓ Extracted in 2.96s (1217→249 tokens)
#
#   [6/30] Senior Data Scientist, Analytics...
#
#   [6/30] Senior Data Scientist, Analytics...
#     ✓ Extracted in 2.71s (662→321 tokens)
#     ✓ Extracted in 2.71s (662→321 tokens)
#
#   [7/30] Principal Scientist...
#
#   [7/30] Principal Scientist...
#     ✓ Extracted in 3.13s (1057→331 tokens)
#     ✓ Extracted in 3.13s (1057→331 tokens)
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#     ✓ Extracted in 6.24s (1586→515 tokens)
#     ✓ Extracted in 6.24s (1586→515 tokens)
#
#   [9/30] AI Agent Engineer...
#
#   [9/30] AI Agent Engineer...
#     ✓ Extracted in 2.32s (645→193 tokens)
#     ✓ Extracted in 2.32s (645→193 tokens)
#
#   [10/30] AI Solutions Engineer (New York)...
#
#   [10/30] AI Solutions Engineer (New York)...
#     ✓ Extracted in 3.31s (1443→327 tokens)
#     ✓ Extracted in 3.31s (1443→327 tokens)
#
#   [11/30] Member of Technical Staff, ML Engineer...
#
#   [11/30] Member of Technical Staff, ML Engineer...
#     ✓ Extracted in 4.13s (1133→310 tokens)
#     ✓ Extracted in 4.13s (1133→310 tokens)
#
#   [12/30] Consultant, Healthcare Informatics...
#
#   [12/30] Consultant, Healthcare Informatics...
#     ✓ Extracted in 4.11s (1242→431 tokens)
#     ✓ Extracted in 4.11s (1242→431 tokens)
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#     ✓ Extracted in 4.59s (1101→332 tokens)
#     ✓ Extracted in 4.59s (1101→332 tokens)
#
#   [14/30] Data Scientist- Manager...
#
#   [14/30] Data Scientist- Manager...
#     ✓ Extracted in 6.57s (1313→389 tokens)
#     ✓ Extracted in 6.57s (1313→389 tokens)
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#     ✓ Extracted in 3.90s (1487→249 tokens)
#     ✓ Extracted in 3.90s (1487→249 tokens)
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#     ✓ Extracted in 6.30s (2119→489 tokens)
#     ✓ Extracted in 6.30s (2119→489 tokens)
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: expected value at line 1 co
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: expected value at line 1 co
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#     ✓ Extracted in 4.63s (1013→224 tokens)
#     ✓ Extracted in 4.63s (1013→224 tokens)
#
#   [19/30] Business Analyst Intern...
#
#   [19/30] Business Analyst Intern...
#     ✓ Extracted in 3.80s (715→276 tokens)
#     ✓ Extracted in 3.80s (715→276 tokens)
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: expected value at line 1 co
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: expected value at line 1 co
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: expected value at line 1 co
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: expected value at line 1 co
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#     ✓ Extracted in 3.05s (898→327 tokens)
#     ✓ Extracted in 3.05s (898→327 tokens)
#
#   [23/30] Data Scientist Assurance...
#
#   [23/30] Data Scientist Assurance...
#     ✓ Extracted in 5.18s (538→344 tokens)
#     ✓ Extracted in 5.18s (538→344 tokens)
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#     ✓ Extracted in 4.72s (1176→256 tokens)
#     ✓ Extracted in 4.72s (1176→256 tokens)
#
#   [25/30] STAGE - Data Scientist F/H...
#
#   [25/30] STAGE - Data Scientist F/H...
#     ✓ Extracted in 4.38s (1402→446 tokens)
#     ✓ Extracted in 4.38s (1402→446 tokens)
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#     ✓ Extracted in 4.01s (1698→261 tokens)
#     ✓ Extracted in 4.01s (1698→261 tokens)
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#     ✓ Extracted in 3.21s (1603→322 tokens)
#     ✓ Extracted in 3.21s (1603→322 tokens)
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: expected value at line 1 co
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: expected value at line 1 co
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [30/30] Stage Data Scientist (H/F)...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [30/30] Stage Data Scientist (H/F)...
#     ✓ Extracted in 5.10s (1225→257 tokens)
#     ✓ Extracted in 5.10s (1225→257 tokens)
#
# ======================================================================
# COMBINATION 2/14: qwen3:1.7b-q4_K_M + examples
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#
# ======================================================================
# COMBINATION 2/14: qwen3:1.7b-q4_K_M + examples
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#     ✓ Extracted in 7.46s (1746→302 tokens)
#     ✓ Extracted in 7.46s (1746→302 tokens)
#
#   [2/30] Data Engineer...
#
#   [2/30] Data Engineer...
#     ✓ Extracted in 6.13s (1865→305 tokens)
#     ✓ Extracted in 6.13s (1865→305 tokens)
#
#   [3/30] Data Scientist...
#
#   [3/30] Data Scientist...
#     ✓ Extracted in 3.48s (1624→281 tokens)
#     ✓ Extracted in 3.48s (1624→281 tokens)
#
#   [4/30] Data Scientist, Music Expression...
#
#   [4/30] Data Scientist, Music Expression...
#     ✓ Extracted in 11.52s (1694→260 tokens)
#     ✓ Extracted in 11.52s (1694→260 tokens)
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#     ✓ Extracted in 8.71s (1702→152 tokens)
#     ✓ Extracted in 8.71s (1702→152 tokens)
#
#   [6/30] Senior Data Scientist, Analytics...
#
#   [6/30] Senior Data Scientist, Analytics...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [7/30] Principal Scientist...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [7/30] Principal Scientist...
#     ✓ Extracted in 3.82s (1542→392 tokens)
#     ✓ Extracted in 3.82s (1542→392 tokens)
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#     ✓ Extracted in 5.05s (2071→277 tokens)
#     ✓ Extracted in 5.05s (2071→277 tokens)
#
#   [9/30] AI Agent Engineer...
#
#   [9/30] AI Agent Engineer...
#     ✓ Extracted in 6.97s (1130→243 tokens)
#     ✓ Extracted in 6.97s (1130→243 tokens)
#
#   [10/30] AI Solutions Engineer (New York)...
#
#   [10/30] AI Solutions Engineer (New York)...
#     ✓ Extracted in 6.80s (1928→279 tokens)
#     ✓ Extracted in 6.80s (1928→279 tokens)
#
#   [11/30] Member of Technical Staff, ML Engineer...
#
#   [11/30] Member of Technical Staff, ML Engineer...
#     ✓ Extracted in 5.25s (1618→255 tokens)
#     ✓ Extracted in 5.25s (1618→255 tokens)
#
#   [12/30] Consultant, Healthcare Informatics...
#
#   [12/30] Consultant, Healthcare Informatics...
#     ✓ Extracted in 5.35s (1727→268 tokens)
#     ✓ Extracted in 5.35s (1727→268 tokens)
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#     ✓ Extracted in 3.57s (1586→442 tokens)
#     ✓ Extracted in 3.57s (1586→442 tokens)
#
#   [14/30] Data Scientist- Manager...
#
#   [14/30] Data Scientist- Manager...
#     ✓ Extracted in 5.37s (1798→382 tokens)
#     ✓ Extracted in 5.37s (1798→382 tokens)
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#     ✓ Extracted in 4.15s (1972→215 tokens)
#     ✓ Extracted in 4.15s (1972→215 tokens)
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#     ✓ Extracted in 4.91s (2604→467 tokens)
#     ✓ Extracted in 4.91s (2604→467 tokens)
#     ✗ Judge gpt-4o error: OpenAI refused to answer the request: json```json
# {
#   "completeness_score": 8,
#
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#     ✗ Judge gpt-4o error: OpenAI refused to answer the request: json```json
# {
#   "completeness_score": 8,
#
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#     ✓ Extracted in 3.28s (1613→383 tokens)
#     ✓ Extracted in 3.28s (1613→383 tokens)
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#     ✓ Extracted in 5.33s (1498→191 tokens)
#     ✓ Extracted in 5.33s (1498→191 tokens)
#
#   [19/30] Business Analyst Intern...
#
#   [19/30] Business Analyst Intern...
#     ✓ Extracted in 4.32s (1200→294 tokens)
#     ✓ Extracted in 4.32s (1200→294 tokens)
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#     ✓ Extracted in 10.93s (2171→64 tokens)
#     ✓ Extracted in 10.93s (2171→64 tokens)
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#     ✓ Extracted in 8.03s (2393→450 tokens)
#     ✓ Extracted in 8.03s (2393→450 tokens)
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#     ✓ Extracted in 4.08s (1383→275 tokens)
#     ✓ Extracted in 4.08s (1383→275 tokens)
#
#   [23/30] Data Scientist Assurance...
#
#   [23/30] Data Scientist Assurance...
#     ✓ Extracted in 2.96s (1023→314 tokens)
#     ✓ Extracted in 2.96s (1023→314 tokens)
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#     ✓ Extracted in 2.32s (1661→192 tokens)
#     ✓ Extracted in 2.32s (1661→192 tokens)
#
#   [25/30] STAGE - Data Scientist F/H...
#
#   [25/30] STAGE - Data Scientist F/H...
#     ✓ Extracted in 6.06s (1887→402 tokens)
#     ✓ Extracted in 6.06s (1887→402 tokens)
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#     ✓ Extracted in 3.73s (2183→439 tokens)
#     ✓ Extracted in 3.73s (2183→439 tokens)
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#     ✓ Extracted in 3.52s (2088→301 tokens)
#     ✓ Extracted in 3.52s (2088→301 tokens)
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#     ✓ Extracted in 6.66s (2314→249 tokens)
#     ✓ Extracted in 6.66s (2314→249 tokens)
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#     ✓ Extracted in 3.53s (2380→440 tokens)
#     ✓ Extracted in 3.53s (2380→440 tokens)
#
#   [30/30] Stage Data Scientist (H/F)...
#
#   [30/30] Stage Data Scientist (H/F)...
#     ✓ Extracted in 3.70s (1710→423 tokens)
#     ✓ Extracted in 3.70s (1710→423 tokens)
#
# ======================================================================
# COMBINATION 3/14: qwen3:4b-q4_K_M + direct
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#
# ======================================================================
# COMBINATION 3/14: qwen3:4b-q4_K_M + direct
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#     ✓ Extracted in 7.00s (1261→326 tokens)
#     ✓ Extracted in 7.00s (1261→326 tokens)
#
#   [2/30] Data Engineer...
#
#   [2/30] Data Engineer...
#     ✓ Extracted in 192.34s (1380→76 tokens)
#     ✓ Extracted in 192.34s (1380→76 tokens)
#
#   [3/30] Data Scientist...
#
#   [3/30] Data Scientist...
#     ✓ Extracted in 6.14s (1139→343 tokens)
#     ✓ Extracted in 6.14s (1139→343 tokens)
#
#   [4/30] Data Scientist, Music Expression...
#
#   [4/30] Data Scientist, Music Expression...
#     ✓ Extracted in 9.08s (1209→364 tokens)
#     ✓ Extracted in 9.08s (1209→364 tokens)
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#     ✓ Extracted in 4.28s (1217→256 tokens)
#     ✓ Extracted in 4.28s (1217→256 tokens)
#
#   [6/30] Senior Data Scientist, Analytics...
#
#   [6/30] Senior Data Scientist, Analytics...
#     ✓ Extracted in 12.20s (662→267 tokens)
#     ✓ Extracted in 12.20s (662→267 tokens)
#
#   [7/30] Principal Scientist...
#
#   [7/30] Principal Scientist...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#     ✓ Extracted in 6.17s (1586→401 tokens)
#     ✓ Extracted in 6.17s (1586→401 tokens)
#
#   [9/30] AI Agent Engineer...
#
#   [9/30] AI Agent Engineer...
#     ✓ Extracted in 8.69s (645→258 tokens)
#     ✓ Extracted in 8.69s (645→258 tokens)
#
#   [10/30] AI Solutions Engineer (New York)...
#
#   [10/30] AI Solutions Engineer (New York)...
#     ✓ Extracted in 6.31s (1443→352 tokens)
#     ✓ Extracted in 6.31s (1443→352 tokens)
#
#   [11/30] Member of Technical Staff, ML Engineer...
#
#   [11/30] Member of Technical Staff, ML Engineer...
#     ✓ Extracted in 6.21s (1133→437 tokens)
#     ✓ Extracted in 6.21s (1133→437 tokens)
#
#   [12/30] Consultant, Healthcare Informatics...
#
#   [12/30] Consultant, Healthcare Informatics...
#     ✓ Extracted in 5.42s (1242→403 tokens)
#     ✓ Extracted in 5.42s (1242→403 tokens)
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#     ✓ Extracted in 9.23s (1101→388 tokens)
#     ✓ Extracted in 9.23s (1101→388 tokens)
#
#   [14/30] Data Scientist- Manager...
#
#   [14/30] Data Scientist- Manager...
#     ✓ Extracted in 9.05s (1313→427 tokens)
#     ✓ Extracted in 9.05s (1313→427 tokens)
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#     ✓ Extracted in 29.89s (1487→61 tokens)
#     ✓ Extracted in 29.89s (1487→61 tokens)
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#     ✓ Extracted in 6.71s (2119→308 tokens)
#     ✓ Extracted in 6.71s (2119→308 tokens)
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#     ✓ Extracted in 9.42s (1128→330 tokens)
#     ✓ Extracted in 9.42s (1128→330 tokens)
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#     ✓ Extracted in 4.83s (1013→228 tokens)
#     ✓ Extracted in 4.83s (1013→228 tokens)
#
#   [19/30] Business Analyst Intern...
#
#   [19/30] Business Analyst Intern...
#     ✓ Extracted in 9.01s (715→324 tokens)
#     ✓ Extracted in 9.01s (715→324 tokens)
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#     ✓ Extracted in 8.74s (1686→492 tokens)
#     ✓ Extracted in 8.74s (1686→492 tokens)
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#     ✓ Extracted in 5.79s (1908→444 tokens)
#     ✓ Extracted in 5.79s (1908→444 tokens)
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#     ✓ Extracted in 4.15s (898→224 tokens)
#     ✓ Extracted in 4.15s (898→224 tokens)
#
#   [23/30] Data Scientist Assurance...
#
#   [23/30] Data Scientist Assurance...
#     ✓ Extracted in 5.99s (538→320 tokens)
#     ✓ Extracted in 5.99s (538→320 tokens)
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#     ✓ Extracted in 4.42s (1176→236 tokens)
#     ✓ Extracted in 4.42s (1176→236 tokens)
#
#   [25/30] STAGE - Data Scientist F/H...
#
#   [25/30] STAGE - Data Scientist F/H...
#     ✓ Extracted in 7.79s (1402→445 tokens)
#     ✓ Extracted in 7.79s (1402→445 tokens)
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#     ✓ Extracted in 7.02s (1698→362 tokens)
#     ✓ Extracted in 7.02s (1698→362 tokens)
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#     ✓ Extracted in 5.23s (1603→271 tokens)
#     ✓ Extracted in 5.23s (1603→271 tokens)
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#     ✓ Extracted in 5.37s (1829→309 tokens)
#     ✓ Extracted in 5.37s (1829→309 tokens)
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#     ✓ Extracted in 9.16s (1895→486 tokens)
#     ✓ Extracted in 9.16s (1895→486 tokens)
#
#   [30/30] Stage Data Scientist (H/F)...
#
#   [30/30] Stage Data Scientist (H/F)...
#     ✓ Extracted in 15.63s (1225→511 tokens)
#     ✓ Extracted in 15.63s (1225→511 tokens)
#
# ======================================================================
# COMBINATION 4/14: qwen3:4b-q4_K_M + examples
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#
# ======================================================================
# COMBINATION 4/14: qwen3:4b-q4_K_M + examples
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#     ✓ Extracted in 7.54s (1746→376 tokens)
#     ✓ Extracted in 7.54s (1746→376 tokens)
#
#   [2/30] Data Engineer...
#
#   [2/30] Data Engineer...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [3/30] Data Scientist...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [3/30] Data Scientist...
#     ✓ Extracted in 9.22s (1624→310 tokens)
#     ✓ Extracted in 9.22s (1624→310 tokens)
#
#   [4/30] Data Scientist, Music Expression...
#
#   [4/30] Data Scientist, Music Expression...
#     ✓ Extracted in 7.13s (1694→377 tokens)
#     ✓ Extracted in 7.13s (1694→377 tokens)
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#     ✓ Extracted in 16.39s (1702→244 tokens)
#     ✓ Extracted in 16.39s (1702→244 tokens)
#
#   [6/30] Senior Data Scientist, Analytics...
#
#   [6/30] Senior Data Scientist, Analytics...
#     ✓ Extracted in 13.76s (1147→354 tokens)
#     ✓ Extracted in 13.76s (1147→354 tokens)
#
#   [7/30] Principal Scientist...
#
#   [7/30] Principal Scientist...
#     ✓ Extracted in 13.46s (1542→334 tokens)
#     ✓ Extracted in 13.46s (1542→334 tokens)
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#     ✓ Extracted in 9.29s (2071→456 tokens)
#     ✓ Extracted in 9.29s (2071→456 tokens)
#
#   [9/30] AI Agent Engineer...
#
#   [9/30] AI Agent Engineer...
#     ✓ Extracted in 7.62s (1130→287 tokens)
#     ✓ Extracted in 7.62s (1130→287 tokens)
#
#   [10/30] AI Solutions Engineer (New York)...
#
#   [10/30] AI Solutions Engineer (New York)...
#     ✓ Extracted in 7.04s (1928→363 tokens)
#     ✓ Extracted in 7.04s (1928→363 tokens)
#
#   [11/30] Member of Technical Staff, ML Engineer...
#
#   [11/30] Member of Technical Staff, ML Engineer...
#     ✓ Extracted in 10.54s (1618→469 tokens)
#     ✓ Extracted in 10.54s (1618→469 tokens)
#
#   [12/30] Consultant, Healthcare Informatics...
#
#   [12/30] Consultant, Healthcare Informatics...
#     ✓ Extracted in 8.59s (1727→383 tokens)
#     ✓ Extracted in 8.59s (1727→383 tokens)
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [14/30] Data Scientist- Manager...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [14/30] Data Scientist- Manager...
#     ✓ Extracted in 9.80s (1798→338 tokens)
#     ✓ Extracted in 9.80s (1798→338 tokens)
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#     ✓ Extracted in 10.45s (1972→334 tokens)
#     ✓ Extracted in 10.45s (1972→334 tokens)
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#     ✓ Extracted in 9.05s (1613→370 tokens)
#     ✓ Extracted in 9.05s (1613→370 tokens)
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#     ✓ Extracted in 10.15s (1498→245 tokens)
#     ✓ Extracted in 10.15s (1498→245 tokens)
#
#   [19/30] Business Analyst Intern...
#
#   [19/30] Business Analyst Intern...
#     ✓ Extracted in 8.56s (1200→270 tokens)
#     ✓ Extracted in 8.56s (1200→270 tokens)
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#     ✓ Extracted in 18.18s (2171→524 tokens)
#     ✓ Extracted in 18.18s (2171→524 tokens)
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#     ✓ Extracted in 7.07s (2393→455 tokens)
#     ✓ Extracted in 7.07s (2393→455 tokens)
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#     ✓ Extracted in 8.77s (1383→253 tokens)
#     ✓ Extracted in 8.77s (1383→253 tokens)
#
#   [23/30] Data Scientist Assurance...
#
#   [23/30] Data Scientist Assurance...
#     ✓ Extracted in 11.80s (1023→304 tokens)
#     ✓ Extracted in 11.80s (1023→304 tokens)
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#     ✓ Extracted in 6.33s (1661→219 tokens)
#     ✓ Extracted in 6.33s (1661→219 tokens)
#
#   [25/30] STAGE - Data Scientist F/H...
#
#   [25/30] STAGE - Data Scientist F/H...
#     ✓ Extracted in 12.01s (1887→341 tokens)
#     ✓ Extracted in 12.01s (1887→341 tokens)
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#     ✓ Extracted in 77.01s (2183→82 tokens)
#     ✓ Extracted in 77.01s (2183→82 tokens)
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#     ✓ Extracted in 6.35s (2088→325 tokens)
#     ✓ Extracted in 6.35s (2088→325 tokens)
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#     ✓ Extracted in 5.99s (2314→385 tokens)
#     ✓ Extracted in 5.99s (2314→385 tokens)
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#     ✓ Extracted in 71.37s (2380→28 tokens)
#     ✓ Extracted in 71.37s (2380→28 tokens)
#
#   [30/30] Stage Data Scientist (H/F)...
#
#   [30/30] Stage Data Scientist (H/F)...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
# ======================================================================
# COMBINATION 5/14: qwen3:4b-instruct-2507-q4_K_M + direct
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
# ======================================================================
# COMBINATION 5/14: qwen3:4b-instruct-2507-q4_K_M + direct
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#     ✓ Extracted in 4.14s (1261→367 tokens)
#     ✓ Extracted in 4.14s (1261→367 tokens)
#
#   [2/30] Data Engineer...
#
#   [2/30] Data Engineer...
#     ✓ Extracted in 2.15s (1380→363 tokens)
#     ✓ Extracted in 2.15s (1380→363 tokens)
#
#   [3/30] Data Scientist...
#
#   [3/30] Data Scientist...
#     ✓ Extracted in 2.53s (1139→416 tokens)
#     ✓ Extracted in 2.53s (1139→416 tokens)
#
#   [4/30] Data Scientist, Music Expression...
#
#   [4/30] Data Scientist, Music Expression...
#     ✓ Extracted in 2.50s (1209→411 tokens)
#     ✓ Extracted in 2.50s (1209→411 tokens)
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#     ✓ Extracted in 2.01s (1217→315 tokens)
#     ✓ Extracted in 2.01s (1217→315 tokens)
#
#   [6/30] Senior Data Scientist, Analytics...
#
#   [6/30] Senior Data Scientist, Analytics...
#     ✓ Extracted in 2.15s (662→357 tokens)
#     ✓ Extracted in 2.15s (662→357 tokens)
#
#   [7/30] Principal Scientist...
#
#   [7/30] Principal Scientist...
#     ✓ Extracted in 2.25s (1057→360 tokens)
#     ✓ Extracted in 2.25s (1057→360 tokens)
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#     ✓ Extracted in 3.58s (1586→585 tokens)
#     ✓ Extracted in 3.58s (1586→585 tokens)
#
#   [9/30] AI Agent Engineer...
#
#   [9/30] AI Agent Engineer...
#     ✓ Extracted in 1.91s (645→320 tokens)
#     ✓ Extracted in 1.91s (645→320 tokens)
#
#   [10/30] AI Solutions Engineer (New York)...
#
#   [10/30] AI Solutions Engineer (New York)...
#     ✓ Extracted in 2.65s (1443→421 tokens)
#     ✓ Extracted in 2.65s (1443→421 tokens)
#
#   [11/30] Member of Technical Staff, ML Engineer...
#
#   [11/30] Member of Technical Staff, ML Engineer...
#     ✓ Extracted in 3.55s (1133→604 tokens)
#     ✓ Extracted in 3.55s (1133→604 tokens)
#
#   [12/30] Consultant, Healthcare Informatics...
#
#   [12/30] Consultant, Healthcare Informatics...
#     ✓ Extracted in 3.36s (1242→563 tokens)
#     ✓ Extracted in 3.36s (1242→563 tokens)
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#     ✓ Extracted in 2.02s (1101→334 tokens)
#     ✓ Extracted in 2.02s (1101→334 tokens)
#
#   [14/30] Data Scientist- Manager...
#
#   [14/30] Data Scientist- Manager...
#     ✓ Extracted in 2.49s (1313→414 tokens)
#     ✓ Extracted in 2.49s (1313→414 tokens)
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#     ✓ Extracted in 3.05s (1487→468 tokens)
#     ✓ Extracted in 3.05s (1487→468 tokens)
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#     ✓ Extracted in 3.51s (2119→557 tokens)
#     ✓ Extracted in 3.51s (2119→557 tokens)
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#     ✓ Extracted in 2.29s (1128→390 tokens)
#     ✓ Extracted in 2.29s (1128→390 tokens)
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#     ✓ Extracted in 1.82s (1013→302 tokens)
#     ✓ Extracted in 1.82s (1013→302 tokens)
#
#   [19/30] Business Analyst Intern...
#
#   [19/30] Business Analyst Intern...
#     ✓ Extracted in 1.83s (715→300 tokens)
#     ✓ Extracted in 1.83s (715→300 tokens)
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#     ✓ Extracted in 4.46s (1686→744 tokens)
#     ✓ Extracted in 4.46s (1686→744 tokens)
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#     ✓ Extracted in 3.25s (1908→515 tokens)
#     ✓ Extracted in 3.25s (1908→515 tokens)
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#     ✓ Extracted in 1.89s (898→308 tokens)
#     ✓ Extracted in 1.89s (898→308 tokens)
#
#   [23/30] Data Scientist Assurance...
#
#   [23/30] Data Scientist Assurance...
#     ✓ Extracted in 1.73s (538→305 tokens)
#     ✓ Extracted in 1.73s (538→305 tokens)
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#     ✓ Extracted in 2.18s (1176→364 tokens)
#     ✓ Extracted in 2.18s (1176→364 tokens)
#
#   [25/30] STAGE - Data Scientist F/H...
#
#   [25/30] STAGE - Data Scientist F/H...
#     ✓ Extracted in 2.71s (1402→454 tokens)
#     ✓ Extracted in 2.71s (1402→454 tokens)
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#     ✓ Extracted in 4.00s (1698→669 tokens)
#     ✓ Extracted in 4.00s (1698→669 tokens)
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#     ✓ Extracted in 2.02s (1603→314 tokens)
#     ✓ Extracted in 2.02s (1603→314 tokens)
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#     ✓ Extracted in 3.47s (1829→564 tokens)
#     ✓ Extracted in 3.47s (1829→564 tokens)
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#     ✓ Extracted in 4.42s (1895→713 tokens)
#     ✓ Extracted in 4.42s (1895→713 tokens)
#
#   [30/30] Stage Data Scientist (H/F)...
#
#   [30/30] Stage Data Scientist (H/F)...
#     ✓ Extracted in 1.78s (1225→283 tokens)
#     ✓ Extracted in 1.78s (1225→283 tokens)
#
# ======================================================================
# COMBINATION 6/14: qwen3:4b-instruct-2507-q4_K_M + examples
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#
# ======================================================================
# COMBINATION 6/14: qwen3:4b-instruct-2507-q4_K_M + examples
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#     ✓ Extracted in 2.54s (1746→391 tokens)
#     ✓ Extracted in 2.54s (1746→391 tokens)
#
#   [2/30] Data Engineer...
#
#   [2/30] Data Engineer...
#     ✓ Extracted in 2.62s (1865→422 tokens)
#     ✓ Extracted in 2.62s (1865→422 tokens)
#
#   [3/30] Data Scientist...
#
#   [3/30] Data Scientist...
#     ✓ Extracted in 2.62s (1624→415 tokens)
#     ✓ Extracted in 2.62s (1624→415 tokens)
#
#   [4/30] Data Scientist, Music Expression...
#
#   [4/30] Data Scientist, Music Expression...
#     ✓ Extracted in 3.05s (1694→501 tokens)
#     ✓ Extracted in 3.05s (1694→501 tokens)
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#     ✓ Extracted in 2.62s (1702→420 tokens)
#     ✓ Extracted in 2.62s (1702→420 tokens)
#
#   [6/30] Senior Data Scientist, Analytics...
#
#   [6/30] Senior Data Scientist, Analytics...
#     ✓ Extracted in 2.62s (1147→448 tokens)
#     ✓ Extracted in 2.62s (1147→448 tokens)
#
#   [7/30] Principal Scientist...
#
#   [7/30] Principal Scientist...
#     ✓ Extracted in 3.50s (1542→565 tokens)
#     ✓ Extracted in 3.50s (1542→565 tokens)
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#     ✓ Extracted in 4.11s (2071→676 tokens)
#     ✓ Extracted in 4.11s (2071→676 tokens)
#
#   [9/30] AI Agent Engineer...
#
#   [9/30] AI Agent Engineer...
#     ✓ Extracted in 2.59s (1130→430 tokens)
#     ✓ Extracted in 2.59s (1130→430 tokens)
#
#   [10/30] AI Solutions Engineer (New York)...
#
#   [10/30] AI Solutions Engineer (New York)...
#     ✓ Extracted in 3.81s (1928→604 tokens)
#     ✓ Extracted in 3.81s (1928→604 tokens)
#
#   [11/30] Member of Technical Staff, ML Engineer...
#
#   [11/30] Member of Technical Staff, ML Engineer...
#     ✓ Extracted in 3.90s (1618→632 tokens)
#     ✓ Extracted in 3.90s (1618→632 tokens)
#
#   [12/30] Consultant, Healthcare Informatics...
#
#   [12/30] Consultant, Healthcare Informatics...
#     ✓ Extracted in 3.71s (1727→620 tokens)
#     ✓ Extracted in 3.71s (1727→620 tokens)
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#     ✓ Extracted in 2.61s (1586→424 tokens)
#     ✓ Extracted in 2.61s (1586→424 tokens)
#
#   [14/30] Data Scientist- Manager...
#
#   [14/30] Data Scientist- Manager...
#     ✓ Extracted in 3.17s (1798→544 tokens)
#     ✓ Extracted in 3.17s (1798→544 tokens)
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#     ✓ Extracted in 3.83s (1972→588 tokens)
#     ✓ Extracted in 3.83s (1972→588 tokens)
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#     ✓ Extracted in 4.87s (2604→776 tokens)
#     ✓ Extracted in 4.87s (2604→776 tokens)
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#     ✓ Extracted in 3.53s (1613→578 tokens)
#     ✓ Extracted in 3.53s (1613→578 tokens)
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#     ✓ Extracted in 2.61s (1498→418 tokens)
#     ✓ Extracted in 2.61s (1498→418 tokens)
#
#   [19/30] Business Analyst Intern...
#
#   [19/30] Business Analyst Intern...
#     ✓ Extracted in 2.11s (1200→345 tokens)
#     ✓ Extracted in 2.11s (1200→345 tokens)
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#     ✓ Extracted in 4.94s (2171→813 tokens)
#     ✓ Extracted in 4.94s (2171→813 tokens)
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#     ✓ Extracted in 5.38s (2393→873 tokens)
#     ✓ Extracted in 5.38s (2393→873 tokens)
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#     ✓ Extracted in 2.90s (1383→489 tokens)
#     ✓ Extracted in 2.90s (1383→489 tokens)
#
#   [23/30] Data Scientist Assurance...
#
#   [23/30] Data Scientist Assurance...
#     ✓ Extracted in 2.64s (1023→462 tokens)
#     ✓ Extracted in 2.64s (1023→462 tokens)
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#     ✓ Extracted in 3.08s (1661→512 tokens)
#     ✓ Extracted in 3.08s (1661→512 tokens)
#
#   [25/30] STAGE - Data Scientist F/H...
#
#   [25/30] STAGE - Data Scientist F/H...
#     ✓ Extracted in 3.61s (1887→568 tokens)
#     ✓ Extracted in 3.61s (1887→568 tokens)
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#     ✓ Extracted in 4.68s (2183→776 tokens)
#     ✓ Extracted in 4.68s (2183→776 tokens)
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#     ✓ Extracted in 2.40s (2088→376 tokens)
#     ✓ Extracted in 2.40s (2088→376 tokens)
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#     ✓ Extracted in 3.78s (2314→644 tokens)
#     ✓ Extracted in 3.78s (2314→644 tokens)
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#     ✓ Extracted in 4.57s (2380→776 tokens)
#     ✓ Extracted in 4.57s (2380→776 tokens)
#
#   [30/30] Stage Data Scientist (H/F)...
#
#   [30/30] Stage Data Scientist (H/F)...
#     ✓ Extracted in 2.70s (1710→411 tokens)
#     ✓ Extracted in 2.70s (1710→411 tokens)
#
# ======================================================================
# COMBINATION 7/14: qwen3:8b-q4_K_M + direct
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#
# ======================================================================
# COMBINATION 7/14: qwen3:8b-q4_K_M + direct
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#     ✓ Extracted in 8.70s (1261→371 tokens)
#     ✓ Extracted in 8.70s (1261→371 tokens)
#
#   [2/30] Data Engineer...
#
#   [2/30] Data Engineer...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [3/30] Data Scientist...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [3/30] Data Scientist...
#     ✓ Extracted in 7.39s (1139→327 tokens)
#     ✓ Extracted in 7.39s (1139→327 tokens)
#
#   [4/30] Data Scientist, Music Expression...
#
#   [4/30] Data Scientist, Music Expression...
#     ✓ Extracted in 10.05s (1209→332 tokens)
#     ✓ Extracted in 10.05s (1209→332 tokens)
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#     ✓ Extracted in 7.60s (1217→219 tokens)
#     ✓ Extracted in 7.60s (1217→219 tokens)
#
#   [6/30] Senior Data Scientist, Analytics...
#
#   [6/30] Senior Data Scientist, Analytics...
#     ✓ Extracted in 9.30s (662→292 tokens)
#     ✓ Extracted in 9.30s (662→292 tokens)
#
#   [7/30] Principal Scientist...
#
#   [7/30] Principal Scientist...
#     ✓ Extracted in 10.82s (1057→299 tokens)
#     ✓ Extracted in 10.82s (1057→299 tokens)
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#     ✓ Extracted in 9.48s (1586→451 tokens)
#     ✓ Extracted in 9.48s (1586→451 tokens)
#
#   [9/30] AI Agent Engineer...
#
#   [9/30] AI Agent Engineer...
#     ✓ Extracted in 7.06s (645→270 tokens)
#     ✓ Extracted in 7.06s (645→270 tokens)
#
#   [10/30] AI Solutions Engineer (New York)...
#
#   [10/30] AI Solutions Engineer (New York)...
#     ✓ Extracted in 9.89s (1443→456 tokens)
#     ✓ Extracted in 9.89s (1443→456 tokens)
#
#   [11/30] Member of Technical Staff, ML Engineer...
#
#   [11/30] Member of Technical Staff, ML Engineer...
#     ✓ Extracted in 12.73s (1133→542 tokens)
#     ✓ Extracted in 12.73s (1133→542 tokens)
#
#   [12/30] Consultant, Healthcare Informatics...
#
#   [12/30] Consultant, Healthcare Informatics...
#     ✓ Extracted in 8.79s (1242→431 tokens)
#     ✓ Extracted in 8.79s (1242→431 tokens)
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#     ✓ Extracted in 7.92s (1101→375 tokens)
#     ✓ Extracted in 7.92s (1101→375 tokens)
#
#   [14/30] Data Scientist- Manager...
#
#   [14/30] Data Scientist- Manager...
#     ✓ Extracted in 10.13s (1313→348 tokens)
#     ✓ Extracted in 10.13s (1313→348 tokens)
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#     ✓ Extracted in 11.14s (1487→365 tokens)
#     ✓ Extracted in 11.14s (1487→365 tokens)
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#     ✓ Extracted in 12.45s (2119→566 tokens)
#     ✓ Extracted in 12.45s (2119→566 tokens)
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#     ✓ Extracted in 9.64s (1128→265 tokens)
#     ✓ Extracted in 9.64s (1128→265 tokens)
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#     ✓ Extracted in 5.52s (1013→250 tokens)
#     ✓ Extracted in 5.52s (1013→250 tokens)
#
#   [19/30] Business Analyst Intern...
#
#   [19/30] Business Analyst Intern...
#     ✓ Extracted in 6.69s (715→297 tokens)
#     ✓ Extracted in 6.69s (715→297 tokens)
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#     ✓ Extracted in 9.90s (1686→544 tokens)
#     ✓ Extracted in 9.90s (1686→544 tokens)
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#     ✓ Extracted in 9.68s (1908→433 tokens)
#     ✓ Extracted in 9.68s (1908→433 tokens)
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#     ✓ Extracted in 8.47s (898→218 tokens)
#     ✓ Extracted in 8.47s (898→218 tokens)
#
#   [23/30] Data Scientist Assurance...
#
#   [23/30] Data Scientist Assurance...
#     ✓ Extracted in 8.25s (538→311 tokens)
#     ✓ Extracted in 8.25s (538→311 tokens)
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#     ✓ Extracted in 61.92s (1176→205 tokens)
#     ✓ Extracted in 61.92s (1176→205 tokens)
#
#   [25/30] STAGE - Data Scientist F/H...
#
#   [25/30] STAGE - Data Scientist F/H...
#     ✓ Extracted in 13.88s (1402→417 tokens)
#     ✓ Extracted in 13.88s (1402→417 tokens)
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#     ✓ Extracted in 11.58s (1698→436 tokens)
#     ✓ Extracted in 11.58s (1698→436 tokens)
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#     ✓ Extracted in 9.08s (1603→270 tokens)
#     ✓ Extracted in 9.08s (1603→270 tokens)
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#     ✓ Extracted in 8.82s (1829→328 tokens)
#     ✓ Extracted in 8.82s (1829→328 tokens)
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#     ✓ Extracted in 10.88s (1895→588 tokens)
#     ✓ Extracted in 10.88s (1895→588 tokens)
#
#   [30/30] Stage Data Scientist (H/F)...
#
#   [30/30] Stage Data Scientist (H/F)...
#     ✓ Extracted in 6.60s (1225→336 tokens)
#     ✓ Extracted in 6.60s (1225→336 tokens)
#
# ======================================================================
# COMBINATION 8/14: qwen3:8b-q4_K_M + examples
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#
# ======================================================================
# COMBINATION 8/14: qwen3:8b-q4_K_M + examples
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#     ✓ Extracted in 21.26s (1746→348 tokens)
#     ✓ Extracted in 21.26s (1746→348 tokens)
#
#   [2/30] Data Engineer...
#
#   [2/30] Data Engineer...
#     ✓ Extracted in 24.42s (1865→270 tokens)
#     ✓ Extracted in 24.42s (1865→270 tokens)
#
#   [3/30] Data Scientist...
#
#   [3/30] Data Scientist...
#     ✓ Extracted in 36.33s (1624→254 tokens)
#     ✓ Extracted in 36.33s (1624→254 tokens)
#
#   [4/30] Data Scientist, Music Expression...
#
#   [4/30] Data Scientist, Music Expression...
#     ✓ Extracted in 16.20s (1694→379 tokens)
#     ✓ Extracted in 16.20s (1694→379 tokens)
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#     ✓ Extracted in 20.36s (1702→211 tokens)
#     ✓ Extracted in 20.36s (1702→211 tokens)
#
#   [6/30] Senior Data Scientist, Analytics...
#
#   [6/30] Senior Data Scientist, Analytics...
#     ✓ Extracted in 27.10s (1147→349 tokens)
#     ✓ Extracted in 27.10s (1147→349 tokens)
#
#   [7/30] Principal Scientist...
#
#   [7/30] Principal Scientist...
#     ✓ Extracted in 23.75s (1542→284 tokens)
#     ✓ Extracted in 23.75s (1542→284 tokens)
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#     ✓ Extracted in 14.23s (2071→410 tokens)
#     ✓ Extracted in 14.23s (2071→410 tokens)
#
#   [9/30] AI Agent Engineer...
#
#   [9/30] AI Agent Engineer...
#     ✓ Extracted in 12.62s (1130→329 tokens)
#     ✓ Extracted in 12.62s (1130→329 tokens)
#
#   [10/30] AI Solutions Engineer (New York)...
#
#   [10/30] AI Solutions Engineer (New York)...
#     ✓ Extracted in 12.16s (1928→433 tokens)
#     ✓ Extracted in 12.16s (1928→433 tokens)
#
#   [11/30] Member of Technical Staff, ML Engineer...
#
#   [11/30] Member of Technical Staff, ML Engineer...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [12/30] Consultant, Healthcare Informatics...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [12/30] Consultant, Healthcare Informatics...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#     ✗ Extraction failed: 1 validation error for JobEnrichment
#   Invalid JSON: EOF while parsing a value a
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#     ✓ Extracted in 10.34s (1586→401 tokens)
#     ✓ Extracted in 10.34s (1586→401 tokens)
#
#   [14/30] Data Scientist- Manager...
#
#   [14/30] Data Scientist- Manager...
#     ✓ Extracted in 325.69s (1798→71 tokens)
#     ✓ Extracted in 325.69s (1798→71 tokens)
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#     ✓ Extracted in 24.40s (1972→273 tokens)
#     ✓ Extracted in 24.40s (1972→273 tokens)
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#     ✓ Extracted in 18.70s (2604→232 tokens)
#     ✓ Extracted in 18.70s (2604→232 tokens)
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#     ✓ Extracted in 20.36s (1613→231 tokens)
# ...
#
#   [2/30] Data Engineer...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [3/30] Data Scientist...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [4/30] Data Scientist, Music Expression...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [6/30] Senior Data Scientist, Analytics...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [7/30] Principal Scientist...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [9/30] AI Agent Engineer...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [10/30] AI Solutions Engineer (New York)...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [11/30] Member of Technical Staff, ML Engineer...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [12/30] Consultant, Healthcare Informatics...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [14/30] Data Scientist- Manager...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [19/30] Business Analyst Intern...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [23/30] Data Scientist Assurance...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [25/30] STAGE - Data Scientist F/H...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
#   [30/30] Stage Data Scientist (H/F)...
#     ✗ Extraction failed: model 'qwen3:30b' not found (status code: 404)
#
# ======================================================================
# COMBINATION 13/14: gemini-2.5-flash-lite + direct
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#     ✓ Extracted in 1.64s (1650→407 tokens)
#     ✓ Extracted in 1.64s (1650→407 tokens)
#
#   [2/30] Data Engineer...
#
#   [2/30] Data Engineer...
#     ✓ Extracted in 1.35s (1779→284 tokens)
#     ✓ Extracted in 1.35s (1779→284 tokens)
#
#   [3/30] Data Scientist...
#
#   [3/30] Data Scientist...
#     ✓ Extracted in 1.59s (1516→329 tokens)
#     ✓ Extracted in 1.59s (1516→329 tokens)
#
#   [4/30] Data Scientist, Music Expression...
#
#   [4/30] Data Scientist, Music Expression...
#     ✓ Extracted in 2.08s (1592→488 tokens)
#     ✓ Extracted in 2.08s (1592→488 tokens)
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#     ✓ Extracted in 1.84s (1657→348 tokens)
#     ✓ Extracted in 1.84s (1657→348 tokens)
#
#   [6/30] Senior Data Scientist, Analytics...
#
#   [6/30] Senior Data Scientist, Analytics...
#     ✓ Extracted in 2.09s (825→272 tokens)
#     ✓ Extracted in 2.09s (825→272 tokens)
#
#   [7/30] Principal Scientist...
#
#   [7/30] Principal Scientist...
#     ✓ Extracted in 1.84s (1437→354 tokens)
#     ✓ Extracted in 1.84s (1437→354 tokens)
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#     ✓ Extracted in 1.97s (2069→525 tokens)
#     ✓ Extracted in 1.97s (2069→525 tokens)
#
#   [9/30] AI Agent Engineer...
#
#   [9/30] AI Agent Engineer...
#     ✓ Extracted in 1.48s (789→344 tokens)
#     ✓ Extracted in 1.48s (789→344 tokens)
#
#   [10/30] AI Solutions Engineer (New York)...
#
#   [10/30] AI Solutions Engineer (New York)...
#     ✓ Extracted in 2.03s (1869→589 tokens)
#     ✓ Extracted in 2.03s (1869→589 tokens)
#
#   [11/30] Member of Technical Staff, ML Engineer...
#
#   [11/30] Member of Technical Staff, ML Engineer...
#     ✓ Extracted in 1.97s (1387→553 tokens)
#     ✓ Extracted in 1.97s (1387→553 tokens)
#
#   [12/30] Consultant, Healthcare Informatics...
#
#   [12/30] Consultant, Healthcare Informatics...
#     ✓ Extracted in 1.97s (1664→562 tokens)
#     ✓ Extracted in 1.97s (1664→562 tokens)
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#     ✓ Extracted in 1.93s (1436→453 tokens)
#     ✓ Extracted in 1.93s (1436→453 tokens)
#
#   [14/30] Data Scientist- Manager...
#
#   [14/30] Data Scientist- Manager...
#     ✓ Extracted in 2.59s (1750→698 tokens)
#     ✓ Extracted in 2.59s (1750→698 tokens)
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#     ✓ Extracted in 1.72s (1987→416 tokens)
#     ✓ Extracted in 1.72s (1987→416 tokens)
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#     ✓ Extracted in 1.60s (2106→251 tokens)
#     ✓ Extracted in 1.60s (2106→251 tokens)
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#     ✓ Extracted in 1.48s (1157→316 tokens)
#     ✓ Extracted in 1.48s (1157→316 tokens)
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#     ✓ Extracted in 1.23s (1119→275 tokens)
#     ✓ Extracted in 1.23s (1119→275 tokens)
#
#   [19/30] Business Analyst Intern...
#
#   [19/30] Business Analyst Intern...
#     ✓ Extracted in 1.72s (815→253 tokens)
#     ✓ Extracted in 1.72s (815→253 tokens)
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#     ✓ Extracted in 2.58s (1743→650 tokens)
#     ✓ Extracted in 2.58s (1743→650 tokens)
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#     ✓ Extracted in 2.21s (1868→625 tokens)
#     ✓ Extracted in 2.21s (1868→625 tokens)
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#     ✓ Extracted in 1.87s (894→286 tokens)
#     ✓ Extracted in 1.87s (894→286 tokens)
#
#   [23/30] Data Scientist Assurance...
#
#   [23/30] Data Scientist Assurance...
#     ✓ Extracted in 1.59s (549→214 tokens)
#     ✓ Extracted in 1.59s (549→214 tokens)
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#     ✓ Extracted in 1.23s (1150→226 tokens)
#     ✓ Extracted in 1.23s (1150→226 tokens)
#
#   [25/30] STAGE - Data Scientist F/H...
#
#   [25/30] STAGE - Data Scientist F/H...
#     ✓ Extracted in 2.24s (1407→621 tokens)
#     ✓ Extracted in 2.24s (1407→621 tokens)
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#     ✓ Extracted in 1.72s (1665→363 tokens)
#     ✓ Extracted in 1.72s (1665→363 tokens)
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#     ✓ Extracted in 1.51s (1759→244 tokens)
#     ✓ Extracted in 1.51s (1759→244 tokens)
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#     ✓ Extracted in 1.60s (1863→296 tokens)
#     ✓ Extracted in 1.60s (1863→296 tokens)
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#     ✓ Extracted in 3.18s (1861→585 tokens)
#     ✓ Extracted in 3.18s (1861→585 tokens)
#
#   [30/30] Stage Data Scientist (H/F)...
#
#   [30/30] Stage Data Scientist (H/F)...
#     ✓ Extracted in 1.59s (1216→338 tokens)
#     ✓ Extracted in 1.59s (1216→338 tokens)
#
# ======================================================================
# COMBINATION 14/14: gemini-2.5-flash-lite + examples
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#
# ======================================================================
# COMBINATION 14/14: gemini-2.5-flash-lite + examples
# ======================================================================
#
#   [1/30] Senior Machine Learning Engineer, Ads R&D...
#     ✓ Extracted in 2.21s (2059→500 tokens)
#     ✓ Extracted in 2.21s (2059→500 tokens)
#
#   [2/30] Data Engineer...
#
#   [2/30] Data Engineer...
#     ✓ Extracted in 1.84s (2188→445 tokens)
#     ✓ Extracted in 1.84s (2188→445 tokens)
#
#   [3/30] Data Scientist...
#
#   [3/30] Data Scientist...
#     ✓ Extracted in 1.97s (1925→434 tokens)
#     ✓ Extracted in 1.97s (1925→434 tokens)
#
#   [4/30] Data Scientist, Music Expression...
#
#   [4/30] Data Scientist, Music Expression...
#     ✓ Extracted in 2.09s (2001→541 tokens)
#     ✓ Extracted in 2.09s (2001→541 tokens)
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#
#   [5/30] Senior Researcher -- Artificial Intelligence and Machine Lea...
#     ✓ Extracted in 1.60s (2066→368 tokens)
#     ✓ Extracted in 1.60s (2066→368 tokens)
#
#   [6/30] Senior Data Scientist, Analytics...
#
#   [6/30] Senior Data Scientist, Analytics...
#     ✓ Extracted in 1.97s (1234→459 tokens)
#     ✓ Extracted in 1.97s (1234→459 tokens)
#
#   [7/30] Principal Scientist...
#
#   [7/30] Principal Scientist...
#     ✓ Extracted in 1.47s (1847→447 tokens)
#     ✓ Extracted in 1.47s (1847→447 tokens)
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#
#   [8/30] Senior Machine Learning Engineer, AI Insights...
#     ✓ Extracted in 3.07s (2478→719 tokens)
#     ✓ Extracted in 3.07s (2478→719 tokens)
#
#   [9/30] AI Agent Engineer...
#
#   [9/30] AI Agent Engineer...
#     ✓ Extracted in 1.85s (1198→386 tokens)
#     ✓ Extracted in 1.85s (1198→386 tokens)
#
#   [10/30] AI Solutions Engineer (New York)...
#
#   [10/30] AI Solutions Engineer (New York)...
#     ✓ Extracted in 2.15s (2278→601 tokens)
#     ✓ Extracted in 2.15s (2278→601 tokens)
#
#   [11/30] Member of Technical Staff, ML Engineer...
#
#   [11/30] Member of Technical Staff, ML Engineer...
#     ✓ Extracted in 3.19s (1797→693 tokens)
#     ✓ Extracted in 3.19s (1797→693 tokens)
#
#   [12/30] Consultant, Healthcare Informatics...
#
#   [12/30] Consultant, Healthcare Informatics...
#     ✓ Extracted in 2.18s (2073→537 tokens)
#     ✓ Extracted in 2.18s (2073→537 tokens)
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#
#   [13/30] Senior Data & Analytics Analyst - Founding Team...
#     ✓ Extracted in 1.98s (1846→536 tokens)
#     ✓ Extracted in 1.98s (1846→536 tokens)
#
#   [14/30] Data Scientist- Manager...
#
#   [14/30] Data Scientist- Manager...
#     ✓ Extracted in 2.09s (2160→682 tokens)
#     ✓ Extracted in 2.09s (2160→682 tokens)
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#
#   [15/30] Principal Machine Learning Engineer (Cortex Xpanse)...
#     ✓ Extracted in 1.62s (2396→497 tokens)
#     ✓ Extracted in 1.62s (2396→497 tokens)
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#
#   [16/30] Stage - Data Scientist GenAI - F/H/N...
#     ✓ Extracted in 2.58s (2515→548 tokens)
#     ✓ Extracted in 2.58s (2515→548 tokens)
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#
#   [17/30] Consultant Senior Stratégie de transformation Data & IA...
#     ✓ Extracted in 1.73s (1567→365 tokens)
#     ✓ Extracted in 1.73s (1567→365 tokens)
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#
#   [18/30] Internship - Data Scientist/Machine Learning Engineer...
#     ✓ Extracted in 1.84s (1528→408 tokens)
#     ✓ Extracted in 1.84s (1528→408 tokens)
#
#   [19/30] Business Analyst Intern...
#
#   [19/30] Business Analyst Intern...
#     ✓ Extracted in 1.47s (1225→302 tokens)
#     ✓ Extracted in 1.47s (1225→302 tokens)
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#
#   [20/30] STAGE - Ingénieur en qualification automatisée des résultats...
#     ✓ Extracted in 1.97s (2152→547 tokens)
#     ✓ Extracted in 1.97s (2152→547 tokens)
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#
#   [21/30] Spécialiste Conformité Data & IA / IA Gen - F/H...
#     ✓ Extracted in 2.85s (2278→684 tokens)
#     ✓ Extracted in 2.85s (2278→684 tokens)
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#
#   [22/30] STAGE - DATA SCIENTIST - F/H...
#     ✓ Extracted in 1.97s (1304→357 tokens)
#     ✓ Extracted in 1.97s (1304→357 tokens)
#
#   [23/30] Data Scientist Assurance...
#
#   [23/30] Data Scientist Assurance...
#     ✓ Extracted in 1.94s (958→282 tokens)
#     ✓ Extracted in 1.94s (958→282 tokens)
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#
#   [24/30] Assistant Data Analyst Durabilité F/H...
#     ✓ Extracted in 1.47s (1559→256 tokens)
#     ✓ Extracted in 1.47s (1559→256 tokens)
#
#   [25/30] STAGE - Data Scientist F/H...
#
#   [25/30] STAGE - Data Scientist F/H...
#     ✓ Extracted in 2.46s (1817→490 tokens)
#     ✓ Extracted in 2.46s (1817→490 tokens)
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#
#   [26/30] Data Analyst - Application Mobile Alternance...
#     ✓ Extracted in 2.25s (2074→496 tokens)
#     ✓ Extracted in 2.25s (2074→496 tokens)
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#
#   [27/30] INTERNSHIP - AI for Thermal Hydraulics - 6 months - Saclay H...
#     ✓ Extracted in 1.53s (2169→369 tokens)
#     ✓ Extracted in 1.53s (2169→369 tokens)
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#
#   [28/30] STA Bac+5 Data Scientist - H/F...
#     ✓ Extracted in 2.78s (2272→443 tokens)
#     ✓ Extracted in 2.78s (2272→443 tokens)
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#
#   [29/30] Consultant·e Data Scientist & AI Engineer - Senior...
#     ✓ Extracted in 2.49s (2271→548 tokens)
#     ✓ Extracted in 2.49s (2271→548 tokens)
#
#   [30/30] Stage Data Scientist (H/F)...
#
#   [30/30] Stage Data Scientist (H/F)...
#     ✓ Extracted in 1.84s (1625→384 tokens)
#     ✓ Extracted in 1.84s (1625→384 tokens)
#
# ==================================================
# EXPERIMENT COMPLETED!
# ==================================================
#
# ✓ Results saved to: extraction_experiment_results.csv and .pkl
# ✓ New columns included: prompt_version, input_tokens, output_tokens, description_length, description_language
#
# ==================================================
# EXPERIMENT COMPLETED!
# ==================================================
#
# ✓ Results saved to: extraction_experiment_results.csv and .pkl
# ✓ New columns included: prompt_version, input_tokens, output_tokens, description_length, description_language

# %%
# Analyze
analyze_results(results_df)
# Out:
# === MODEL PERFORMANCE BY JUDGE & PROMPT ===
#
# --- Judge: claude-sonnet-4-5 ---
#                                              completeness_score        \
#                                                            mean   std
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct                       8.37  0.61
#                               examples                     8.53  0.57
# qwen3:1.7b-q4_K_M             direct                       7.36  0.95
#                               examples                     6.17  1.47
# qwen3:14b-q4_K_M              direct                       8.43  0.63
#                               examples                     8.07  1.27
# qwen3:30b                     direct                        NaN   NaN
#                               examples                      NaN   NaN
# qwen3:4b-instruct-2507-q4_K_M direct                       8.57  0.50
#                               examples                     8.00  0.74
# qwen3:4b-q4_K_M               direct                       7.83  1.71
#                               examples                     7.58  1.96
# qwen3:8b-q4_K_M               direct                       8.34  1.23
#                               examples                     7.11  1.83
#
#                                              accuracy_score        \
#                                                        mean   std
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct                   9.67  0.71
#                               examples                 9.37  0.81
# qwen3:1.7b-q4_K_M             direct                   8.32  1.38
#                               examples                 7.03  2.10
# qwen3:14b-q4_K_M              direct                   9.70  0.70
#                               examples                 9.54  1.35
# qwen3:30b                     direct                    NaN   NaN
#                               examples                  NaN   NaN
# qwen3:4b-instruct-2507-q4_K_M direct                   9.67  0.48
#                               examples                 8.10  1.24
# qwen3:4b-q4_K_M               direct                   8.79  2.18
#                               examples                 8.88  2.03
# qwen3:8b-q4_K_M               direct                   9.38  1.50
#                               examples                 9.07  1.52
#
#                                              specificity_score        \
#                                                           mean   std
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct                      8.13  0.82
#                               examples                    8.37  0.89
# qwen3:1.7b-q4_K_M             direct                      7.32  1.31
#                               examples                    6.62  1.24
# qwen3:14b-q4_K_M              direct                      8.60  0.77
#                               examples                    8.25  1.29
# qwen3:30b                     direct                       NaN   NaN
#                               examples                     NaN   NaN
# qwen3:4b-instruct-2507-q4_K_M direct                      8.50  0.63
#                               examples                    8.03  0.89
# qwen3:4b-q4_K_M               direct                      7.86  2.00
#                               examples                    7.58  2.18
# qwen3:8b-q4_K_M               direct                      8.28  1.03
#                               examples                    7.85  1.41
#
#                                              hallucination_score        \
#                                                             mean   std
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct                        9.73  0.69
#                               examples                      9.40  1.04
# qwen3:1.7b-q4_K_M             direct                        8.08  2.47
#                               examples                      6.10  3.04
# qwen3:14b-q4_K_M              direct                        9.70  0.88
#                               examples                      9.39  1.64
# qwen3:30b                     direct                         NaN   NaN
#                               examples                       NaN   NaN
# qwen3:4b-instruct-2507-q4_K_M direct                        9.83  0.46
#                               examples                      6.70  1.39
# qwen3:4b-q4_K_M               direct                        8.55  2.52
#                               examples                      8.92  1.81
# qwen3:8b-q4_K_M               direct                        9.41  1.80
#                               examples                      9.07  2.06
#
#                                              extraction_time         \
#                                                         mean    std
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct                    1.85   0.42
#                               examples                  2.08   0.46
# qwen3:1.7b-q4_K_M             direct                    4.15   1.13
#                               examples                  5.41   2.27
# qwen3:14b-q4_K_M              direct                   16.47   4.18
#                               examples                 20.72   9.26
# qwen3:30b                     direct                     NaN    NaN
#                               examples                   NaN    NaN
# qwen3:4b-instruct-2507-q4_K_M direct                    2.72   0.85
#                               examples                  3.37   0.87
# qwen3:4b-q4_K_M               direct                   14.53  34.54
#                               examples                 14.75  17.78
# qwen3:8b-q4_K_M               direct                   11.18   9.94
#                               examples                 32.05  59.63
#
#                                              input_tokens           \
#                                                      mean      sum
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct              1485.97  44579.0
#                               examples            1895.33  56860.0
# qwen3:1.7b-q4_K_M             direct              1210.48  30262.0
#                               examples            1796.93  52111.0
# qwen3:14b-q4_K_M              direct              1290.27  38708.0
#                               examples            1771.14  49592.0
# qwen3:30b                     direct                  NaN      0.0
#                               examples                NaN      0.0
# qwen3:4b-instruct-2507-q4_K_M direct              1290.27  38708.0
#                               examples            1775.27  53258.0
# qwen3:4b-q4_K_M               direct              1298.31  37651.0
#                               examples            1749.73  45493.0
# qwen3:8b-q4_K_M               direct              1287.17  37328.0
#                               examples            1793.15  48415.0
#
#                                              output_tokens           \
#                                                       mean      sum
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct                405.50  12165.0
#                               examples              477.47  14324.0
# qwen3:1.7b-q4_K_M             direct                320.00   8000.0
#                               examples              308.17   8937.0
# qwen3:14b-q4_K_M              direct                379.90  11397.0
#                               examples              363.79  10186.0
# qwen3:30b                     direct                   NaN      0.0
#                               examples                 NaN      0.0
# qwen3:4b-instruct-2507-q4_K_M direct                436.00  13080.0
#                               examples              549.90  16497.0
# qwen3:4b-q4_K_M               direct                332.72   9649.0
#                               examples              324.08   8426.0
# qwen3:8b-q4_K_M               direct                363.52  10542.0
#                               examples              289.67   7821.0
#
#                                              extraction_success
#                                                            mean
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct                       1.00
#                               examples                     1.00
# qwen3:1.7b-q4_K_M             direct                       0.83
#                               examples                     0.97
# qwen3:14b-q4_K_M              direct                       1.00
#                               examples                     0.93
# qwen3:30b                     direct                       0.00
#                               examples                     0.00
# qwen3:4b-instruct-2507-q4_K_M direct                       1.00
#                               examples                     1.00
# qwen3:4b-q4_K_M               direct                       0.97
#                               examples                     0.87
# qwen3:8b-q4_K_M               direct                       0.97
#                               examples                     0.90
#
# --- Judge: gpt-4o ---
#                                              completeness_score        \
#                                                            mean   std
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct                       8.03  0.41
#                               examples                     8.27  0.45
# qwen3:1.7b-q4_K_M             direct                       8.00  0.29
#                               examples                     7.32  1.06
# qwen3:14b-q4_K_M              direct                       8.03  0.61
#                               examples                     8.04  0.92
# qwen3:30b                     direct                        NaN   NaN
#                               examples                      NaN   NaN
# qwen3:4b-instruct-2507-q4_K_M direct                       8.27  0.52
#                               examples                     8.33  0.71
# qwen3:4b-q4_K_M               direct                       7.86  1.16
#                               examples                     7.81  1.17
# qwen3:8b-q4_K_M               direct                       8.00  0.96
#                               examples                     7.56  1.12
#
#                                              accuracy_score        \
#                                                        mean   std
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct                   9.13  0.51
#                               examples                 9.10  0.31
# qwen3:1.7b-q4_K_M             direct                   9.08  0.28
#                               examples                 8.18  1.02
# qwen3:14b-q4_K_M              direct                   9.10  0.48
#                               examples                 9.07  0.77
# qwen3:30b                     direct                    NaN   NaN
#                               examples                  NaN   NaN
# qwen3:4b-instruct-2507-q4_K_M direct                   9.30  0.53
#                               examples                 9.23  0.50
# qwen3:4b-q4_K_M               direct                   8.83  1.36
#                               examples                 8.58  1.39
# qwen3:8b-q4_K_M               direct                   8.97  1.21
#                               examples                 8.89  0.70
#
#                                              specificity_score        \
#                                                           mean   std
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct                      8.70  0.47
#                               examples                    8.83  0.38
# qwen3:1.7b-q4_K_M             direct                      8.56  0.65
#                               examples                    8.00  1.25
# qwen3:14b-q4_K_M              direct                      8.87  0.43
#                               examples                    8.54  0.88
# qwen3:30b                     direct                       NaN   NaN
#                               examples                     NaN   NaN
# qwen3:4b-instruct-2507-q4_K_M direct                      8.77  0.57
#                               examples                    8.53  0.78
# qwen3:4b-q4_K_M               direct                      8.52  1.18
#                               examples                    8.31  1.62
# qwen3:8b-q4_K_M               direct                      8.69  0.93
#                               examples                    8.07  1.27
#
#                                              hallucination_score        \
#                                                             mean   std
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct                        9.93  0.25
#                               examples                      9.90  0.31
# qwen3:1.7b-q4_K_M             direct                        9.88  0.33
#                               examples                      9.25  1.04
# qwen3:14b-q4_K_M              direct                        9.90  0.31
#                               examples                      9.86  0.45
# qwen3:30b                     direct                         NaN   NaN
#                               examples                       NaN   NaN
# qwen3:4b-instruct-2507-q4_K_M direct                        9.97  0.18
#                               examples                      9.73  0.45
# qwen3:4b-q4_K_M               direct                        9.66  1.67
#                               examples                      9.58  1.60
# qwen3:8b-q4_K_M               direct                        9.69  1.31
#                               examples                      9.81  0.56
#
#                                              extraction_time         \
#                                                         mean    std
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct                    1.85   0.42
#                               examples                  2.08   0.46
# qwen3:1.7b-q4_K_M             direct                    4.15   1.13
#                               examples                  5.41   2.27
# qwen3:14b-q4_K_M              direct                   16.47   4.18
#                               examples                 20.72   9.26
# qwen3:30b                     direct                     NaN    NaN
#                               examples                   NaN    NaN
# qwen3:4b-instruct-2507-q4_K_M direct                    2.72   0.85
#                               examples                  3.37   0.87
# qwen3:4b-q4_K_M               direct                   14.53  34.54
#                               examples                 14.75  17.78
# qwen3:8b-q4_K_M               direct                   11.18   9.94
#                               examples                 32.05  59.63
#
#                                              input_tokens           \
#                                                      mean      sum
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct              1485.97  44579.0
#                               examples            1895.33  56860.0
# qwen3:1.7b-q4_K_M             direct              1210.48  30262.0
#                               examples            1796.93  52111.0
# qwen3:14b-q4_K_M              direct              1290.27  38708.0
#                               examples            1771.14  49592.0
# qwen3:30b                     direct                  NaN      0.0
#                               examples                NaN      0.0
# qwen3:4b-instruct-2507-q4_K_M direct              1290.27  38708.0
#                               examples            1775.27  53258.0
# qwen3:4b-q4_K_M               direct              1298.31  37651.0
#                               examples            1749.73  45493.0
# qwen3:8b-q4_K_M               direct              1287.17  37328.0
#                               examples            1793.15  48415.0
#
#                                              output_tokens           \
#                                                       mean      sum
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct                405.50  12165.0
#                               examples              477.47  14324.0
# qwen3:1.7b-q4_K_M             direct                320.00   8000.0
#                               examples              308.17   8937.0
# qwen3:14b-q4_K_M              direct                379.90  11397.0
#                               examples              363.79  10186.0
# qwen3:30b                     direct                   NaN      0.0
#                               examples                 NaN      0.0
# qwen3:4b-instruct-2507-q4_K_M direct                436.00  13080.0
#                               examples              549.90  16497.0
# qwen3:4b-q4_K_M               direct                332.72   9649.0
#                               examples              324.08   8426.0
# qwen3:8b-q4_K_M               direct                363.52  10542.0
#                               examples              289.67   7821.0
#
#                                              extraction_success
#                                                            mean
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct                       1.00
#                               examples                     1.00
# qwen3:1.7b-q4_K_M             direct                       0.83
#                               examples                     0.93
# qwen3:14b-q4_K_M              direct                       1.00
#                               examples                     0.93
# qwen3:30b                     direct                       0.00
#                               examples                     0.00
# qwen3:4b-instruct-2507-q4_K_M direct                       1.00
#                               examples                     1.00
# qwen3:4b-q4_K_M               direct                       0.97
#                               examples                     0.87
# qwen3:8b-q4_K_M               direct                       0.97
#                               examples                     0.90
#
# === PROMPT VERSION COMPARISON ===
#                 completeness_score  accuracy_score  specificity_score  \
# prompt_version
# direct                        8.10            9.18               8.41
# examples                      7.74            8.75               8.09
#
#                 hallucination_score  extraction_time  input_tokens  \
# prompt_version
# direct                         9.55             8.56       1313.50
# examples                       8.96            12.64       1798.41
#
#                 output_tokens
# prompt_version
# direct                 374.76
# examples               389.36
#
# === AVERAGE EXTRACTION TIME (seconds) ===
#                                                 mean     std     min      max
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct           1.847   0.418   1.227    3.178
#                               examples         2.082   0.459   1.467    3.195
# qwen3:4b-instruct-2507-q4_K_M direct           2.724   0.839   1.734    4.461
#                               examples         3.370   0.867   2.106    5.380
# qwen3:1.7b-q4_K_M             direct           4.154   1.120   2.318    6.567
#                               examples         5.413   2.249   2.322   11.519
# qwen3:8b-q4_K_M               direct          11.185   9.857   5.521   61.925
# qwen3:4b-q4_K_M               direct          14.527  34.238   4.148  192.342
#                               examples        14.749  17.601   5.991   77.008
# qwen3:14b-q4_K_M              direct          16.472   4.145  11.493   27.464
#                               examples        20.722   9.179   9.874   41.989
# qwen3:8b-q4_K_M               examples        32.048  59.069   8.935  325.685
# qwen3:30b                     direct             NaN     NaN     NaN      NaN
#                               examples           NaN     NaN     NaN      NaN
#
# === TOKEN USAGE ===
#                                              input_tokens            \
#                                                      mean       sum
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct               1486.0   89158.0
#                               examples             1895.0  113720.0
# qwen3:1.7b-q4_K_M             direct               1210.0   60524.0
#                               examples             1797.0  104222.0
# qwen3:14b-q4_K_M              direct               1290.0   77416.0
#                               examples             1771.0   99184.0
# qwen3:30b                     direct                  NaN       0.0
#                               examples                NaN       0.0
# qwen3:4b-instruct-2507-q4_K_M direct               1290.0   77416.0
#                               examples             1775.0  106516.0
# qwen3:4b-q4_K_M               direct               1298.0   75302.0
#                               examples             1750.0   90986.0
# qwen3:8b-q4_K_M               direct               1287.0   74656.0
#                               examples             1793.0   96830.0
#
#                                              output_tokens
#                                                       mean      sum
# extraction_model              prompt_version
# gemini-2.5-flash-lite         direct                 406.0  24330.0
#                               examples               477.0  28648.0
# qwen3:1.7b-q4_K_M             direct                 320.0  16000.0
#                               examples               308.0  17874.0
# qwen3:14b-q4_K_M              direct                 380.0  22794.0
#                               examples               364.0  20372.0
# qwen3:30b                     direct                   NaN      0.0
#                               examples                 NaN      0.0
# qwen3:4b-instruct-2507-q4_K_M direct                 436.0  26160.0
#                               examples               550.0  32994.0
# qwen3:4b-q4_K_M               direct                 333.0  19298.0
#                               examples               324.0  16852.0
# qwen3:8b-q4_K_M               direct                 364.0  21084.0
#                               examples               290.0  15642.0
#
# === DESCRIPTION LANGUAGE BREAKDOWN ===
# description_language
# English    420
# French     420
# Name: count, dtype: int64
#
# === JUDGE AGREEMENT ===
#
# completeness_score variance across judges:
#   Std dev across judges (mean): 0.48
#   Max difference: 3.00
#
# accuracy_score variance across judges:
#   Std dev across judges (mean): 0.62
#   Max difference: 7.00
#
# specificity_score variance across judges:
#   Std dev across judges (mean): 0.54
#   Max difference: 5.00
#
# hallucination_score variance across judges:
#   Std dev across judges (mean): 0.79
#   Max difference: 10.00
#
# === BEST MODELS PER METRIC (Averaged Across Judges) ===
#
# completeness_score:
# extraction_model               prompt_version
# qwen3:4b-instruct-2507-q4_K_M  direct            8.416667
# gemini-2.5-flash-lite          examples          8.400000
# qwen3:14b-q4_K_M               direct            8.233333
# gemini-2.5-flash-lite          direct            8.200000
# qwen3:8b-q4_K_M                direct            8.172414
# Name: completeness_score, dtype: float64
#
# accuracy_score:
# extraction_model               prompt_version
# qwen3:4b-instruct-2507-q4_K_M  direct            9.483333
# gemini-2.5-flash-lite          direct            9.400000
# qwen3:14b-q4_K_M               direct            9.400000
#                                examples          9.303571
# gemini-2.5-flash-lite          examples          9.233333
# Name: accuracy_score, dtype: float64
#
# specificity_score:
# extraction_model               prompt_version
# qwen3:14b-q4_K_M               direct            8.733333
# qwen3:4b-instruct-2507-q4_K_M  direct            8.633333
# gemini-2.5-flash-lite          examples          8.600000
# qwen3:8b-q4_K_M                direct            8.482759
# gemini-2.5-flash-lite          direct            8.416667
# Name: specificity_score, dtype: float64
#
# hallucination_score:
# extraction_model               prompt_version
# qwen3:4b-instruct-2507-q4_K_M  direct            9.900000
# gemini-2.5-flash-lite          direct            9.833333
# qwen3:14b-q4_K_M               direct            9.800000
# gemini-2.5-flash-lite          examples          9.650000
# qwen3:14b-q4_K_M               examples          9.625000
# Name: hallucination_score, dtype: float64
#
# === COMMON ISSUES ===
#
# Most commonly missed info:
# Team size                                  28
# Reports to                                 21
# Remote work details                        18
# Salary range ($106,200 to $210,000 USD)     8
# Seniority level                             8
# Education requirements                      7
# Location: Issy-les-Moulineaux               6
# Language requirements                       6
# Job title (Data Scientist)                  6
# Education required                          5
# Name: count, dtype: int64
#
# Most commonly too generic:
# reports_to              39
# team_size               38
# seniority_level         22
# experience_years_max    21
# experience_years_min    19
# remote_details          19
# languages               14
# education_required      11
# required_skills         10
# concrete_benefits        9
# Name: count, dtype: int64
#
# Most common fabrications:
# Python - not explicitly mentioned in the job posting                                                                                                                                              2
# SQL - not explicitly mentioned in the job posting                                                                                                                                                 2
# None                                                                                                                                                                                              2
# The 'red_flags' section appears to be analyst commentary rather than extracted information from the job posting - these interpretations are subjective and not explicitly stated in the source    1
# 'Office 365' is listed as a required skill, but the job posting says 'Maitrise du pack office' (not specifically Office 365)                                                                      1
# The claim that 'start date is unusually far in the future' is subjective interpretation not from source                                                                                           1
# The statement about 'concern about clarity of timeline' is editorial opinion                                                                                                                      1
# The claim that '15/03/2026 may indicate a typo or error' is speculation                                                                                                                           1
# The red_flags field is entirely fabricated - the extraction adds editorial commentary and speculation not present in the source                                                                   1
# Some items in preferred_skills (Science des données, Architecture technologique, Déploiement technologique) are from company description, not job requirements section                            1
# Name: count, dtype: int64
